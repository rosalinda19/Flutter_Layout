# %% [markdown]
# <a href="https://colab.research.google.com/github/rosalinda19/Flutter_Layout/blob/master/associon_rule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset = pd.read_csv('titanic.csv')

print(dataset)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd

test_dataset = pd.read_csv('titanic_test.csv')

print(test_dataset)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_data = dataset[["Age","Fare"]]
pos_missing_train = train_data.isnull()
train_data.dropna(inplace = True)

print('Train Data = \n',train_data)
print('Data yang hilang = \n',pos_missing_train)
# Out:
# Train Data =
#        Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 885  39.0  29.1250
# 886  27.0  13.0000
# 887  19.0  30.0000
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [714 rows x 2 columns]
# Data yang hilang =
#         Age   Fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888   True  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
test_data = test_dataset[["Age","Fare"]]
pos_missing_test = test_data.isnull()
test_data.dropna(inplace = True)

print('Test Data = \n',test_data)
print('Data yang hilang = \n',pos_missing_test)
# Out:
# Test Data =
#        Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 409   3.0   13.7750
# 411  37.0   90.0000
# 412  28.0    7.7750
# 414  39.0  108.9000
# 415  38.5    7.2500
#
# [331 rows x 2 columns]
# Data yang hilang =
#         Age   Fare
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 413   True  False
# 414  False  False
# 415  False  False
# 416   True  False
# 417   True  False
#
# [418 rows x 2 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
train_label = dataset[["Survived"]]
pos_missing_train = train_label.isnull()
train_label.dropna(inplace = True)

print('Train Label = \n',train_label)
# Out:
# Train Label =
#       Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
test_label = pd.read_csv('titanic_testlabel.csv')
pos_missing_test = test_label.isnull()
test_label.dropna(inplace = True)

print('Test Label = \n',test_label)
# Out:
# Test Label =
#       PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
train_data = train_data.dropna()
minValTrain = train_data.min()
maxValTrain = train_data.max()
newmin = 0
newmax = 1
minMaxTrain = (train_data-minValTrain)*(newmax-newmin)/(maxValTrain-minValTrain) + newmin

print('Hasil dari = \n' ,train_data)
print('Minmax = \n',minMaxTrain)
# Out:
# Hasil dari =
#            Age      Fare
# 0    0.271174  0.014151
# 1    0.472229  0.139136
# 2    0.321438  0.015469
# 3    0.434531  0.103644
# 4    0.434531  0.015713
# 6    0.673285  0.101229
# 7    0.019854  0.041136
# 8    0.334004  0.021731
# 9    0.170646  0.058694
# 10   0.044986  0.032596
# 11   0.723549  0.051822
# 12   0.246042  0.015713
# 13   0.484795  0.061045
# 14   0.170646  0.015330
# 15   0.685851  0.031230
# 16   0.019854  0.056848
# 18   0.384267  0.035134
# 20   0.434531  0.050749
# 21   0.421965  0.025374
# 22   0.183212  0.015672
# 23   0.346569  0.069291
# 24   0.095250  0.041136
# 25   0.472229  0.061264
# 27   0.233476  0.513342
# 30   0.497361  0.054107
# 33   0.824076  0.020495
# 34   0.346569  0.160387
# 35   0.522493  0.101497
# 37   0.258608  0.015713
# 38   0.220910  0.035134
# 39   0.170646  0.021942
# 40   0.497361  0.018494
# 41   0.334004  0.040989
# 43   0.032420  0.081157
# 44   0.233476  0.015379
# 49   0.220910  0.034743
# ...

# %%
test_data = test_data.dropna()
minValTest = test_data.min()
maxValTest = test_data.max()
newmin = 0
newmax = 1
minMaxTest = (test_data-minValTest)*(newmax-newmin)/(maxValTest-minValTest) + newmin

print('Hasil dari = \n' ,test_data)
print('Minmax = \n',minMaxTest)
# Out:
# Hasil dari =
#            Age      Fare
# 0    0.428248  0.015282
# 1    0.585323  0.013663
# 2    0.773813  0.018909
# 3    0.334004  0.016908
# 4    0.271174  0.023984
# 5    0.170646  0.018006
# 6    0.371701  0.014891
# 7    0.321438  0.056604
# 8    0.220910  0.014110
# 9    0.258608  0.047138
# 11   0.572757  0.050749
# 12   0.283740  0.160574
# 13   0.786378  0.050749
# 14   0.585323  0.119406
# 15   0.296306  0.054107
# 16   0.434531  0.024106
# 17   0.258608  0.014102
# 18   0.334004  0.015469
# 19   0.560191  0.014102
# 20   0.685851  0.115941
# 21   0.107816  0.006189
# 23   0.258608  0.119804
# 24   0.597889  0.512122
# 25   0.623021  0.028302
# 26   0.271174  0.120975
# 27   0.277457  0.014102
# 28   0.509927  0.059532
# 30   0.623021  0.050749
# 31   0.296306  0.061484
# 32   0.409399  0.040160
# 34   0.371701  0.112720
# 35   0.227193  0.014110
# 37   0.258608  0.016908
# 38   0.308872  0.018543
# 40   0.484795  0.026188
# 42   0.509927  0.015322
# ...

# %%
kNN = KNeighborsClassifier(n_neighbors=5, weights='distance')
kNN.fit(train_data, train_label)
test_data = test_data.dropna(axis=0)
class_result = kNN.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-96e2645e10b7> in <module>
#       1 kNN = KNeighborsClassifier(n_neighbors=5, weights='distance')
# ----> 2 kNN.fit(train_data, train_label)
#       3 test_data = test_data.dropna(axis=0)
#       4 class_result = kNN.predict(test_data)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     196         self.weights = _check_weights(self.weights)
#     197
# --> 198         return self._fit(X, y)
#     199
#     200     def predict(self, X):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     398         if self._get_tags()["requires_y"]:
#     399             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 400                 X, y = self._validate_data(X, y, accept_sparse="csr", multi_output=True)
# ...

# %%
kNN = KNeighborsClassifier(n_neighbors=5, weights='distance')
kNN.fit(train_data, train_label)
test_data = test_data.dropna(axis=0)
class_result = kNN.predict(test_data)

# %%
precision_ratio = kNN.score(test_data, test_label)

error_ratio = 1 - precision_ratio

print(error_ratio)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-2b6684c7bbfc> in <module>
# ----> 1 precision_ratio = kNN.score(test_data, test_label)
#       2
#       3 error_ratio = 1 - precision_ratio
#       4
#       5 print(error_ratio)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     649         from .metrics import accuracy_score
#     650
# --> 651         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     652
#     653     def _more_tags(self):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     212             Class labels for each data sample.
#     213         """
# --> 214         neigh_dist, neigh_ind = self.kneighbors(X)
#     215         classes_ = self.classes_
#     216         _y = self._y
#
# ...

# %% [markdown]
# # prak7

# %%
import pandas as pd

dataset = pd.read_csv('transaction.csv')

print(dataset)
# Out:
#        InvoiceNo  StockCode  Qty      InvoiceDate  CustomerID  \
# 0         537626      22725  830  12/7/2010 14:57       12347
# 1         537626      22729  948  12/7/2010 14:57       12347
# 2         537626      22195  695  12/7/2010 14:57       12347
# 3         542237      22725  636  1/26/2011 14:30       12347
# 4         542237      22729  536  1/26/2011 14:30       12347
# ...          ...        ...  ...              ...         ...
# 10541     543911      21700  455  2/14/2011 12:46       17829
# 10542     543911      22111  578  2/14/2011 12:46       17829
# 10543     543911      22112  163  2/14/2011 12:46       17829
# 10544     564428      23296  545  8/25/2011 11:27       17844
# 10545     564428      23294  643  8/25/2011 11:27       17844
#
#                     Country
# 0                   Iceland
# 1                   Iceland
# 2                   Iceland
# 3                   Iceland
# 4                   Iceland
# ...                     ...
# ...

# %%
data = dataset.loc[dataset['Country'] == "Portugal"]
print ('data negara portugal = \n',data)
# Out:
# data negara portugal =
#        InvoiceNo  StockCode  Qty      InvoiceDate  CustomerID   Country
# 101      541430      22195  649   1/18/2011 9:50       12356  Portugal
# 102      541430      22435  460   1/18/2011 9:50       12356  Portugal
# 103      541430      84378  304   1/18/2011 9:50       12356  Portugal
# 104      541430      22646  896   1/18/2011 9:50       12356  Portugal
# 105      541430      84987  157   1/18/2011 9:50       12356  Portugal
# ...         ...        ...  ...              ...         ...       ...
# 7596     547444      22745  292  3/23/2011 10:55       12811  Portugal
# 7597     547444      22747  133  3/23/2011 10:55       12811  Portugal
# 7598     547444      22746  835  3/23/2011 10:55       12811  Portugal
# 7599     547444      23176  878  3/23/2011 10:55       12811  Portugal
# 7600     547444      22968  637  3/23/2011 10:55       12811  Portugal
#
# [367 rows x 6 columns]

# %%
transaksi = data.groupby(['InvoiceNo','StockCode'])['Qty'].sum()

print(transaksi)
# Out:
# InvoiceNo  StockCode
# 537246     21931        926
#            22150        624
#            22271        300
#            22411        252
# 537818     21485        538
#                        ...
# 580734     23319        958
# 581182     21166        501
#            22690        786
#            22692        247
#            23284        853
# Name: Qty, Length: 356, dtype: int64

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

transaksi = transaksi.unstack().reset_index().fillna(0).set_index('InvoiceNo')
transaksi[transaksi>0]=1

frequent_itemsets=apriori(transaksi, min_support=0.2, use_colnames=True)
rules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
print('\nAssociation Rules:\n', rules[['antecedents', 'consequents', 'confidence']])
# Out:
# Association Rules:
#         antecedents     consequents  confidence
# 0          (21928)         (21929)    0.900000
# 1          (21929)         (21928)    1.000000
# 2          (21928)         (22411)    0.900000
# 3          (22411)         (21928)    0.818182
# 4          (21929)         (22411)    1.000000
# 5          (22411)         (21929)    0.818182
# 6   (21928, 21929)         (22411)    1.000000
# 7   (21928, 22411)         (21929)    1.000000
# 8   (21929, 22411)         (21928)    1.000000
# 9          (21928)  (21929, 22411)    0.900000
# 10         (21929)  (21928, 22411)    1.000000
# 11         (22411)  (21928, 21929)    0.818182
